# %% [markdown]
# **PRACTICA OBLIGATORIA**
# _Iniciación a Python_

# %%
# El chatbot tiene que saludar con un: "Buenas tardes, bienvenido al servicio de pedido online, 
# el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana 
# ¿Cuántas pizzas familiares desea?"

pizz_familiar = int(input("Buenas tardes, bienvenido al servicio de pedido online, el precio de nuestra pizzas es de 8,95 para la familiar o de 9,90 para la mediana ¿Cuántas pizzas familiares desea?"))

# El chatbot debe responder: "Estupendo, ¿cuántas pizzas medianas desea?" 
print("Estupendo, ¿cuántas pizzas medianas desea?")

# y guardar el número de pizzas medianas en otra variable 'pizz_mediana'
pizz_mediana = int(input())

# Además debe responder del chatbot: "Estupendo, se están preparando 'pizz' pizzas familiares y 'pizz_mediana' pizzas medianas. Digame su dirección"

print("Estupendo, se están preparando 'pizz' pizzas familiares y 'pizz_mediana' pizzas medianas. Digame su dirección")

# El ususario tiene que introducir una direccion en formato String en otra variable llamada 'direcc'

direcc = str(input())

# El chat contesta el precio 
print("El pedido total seria el siguiente:")
      
precio_familiar = 9.90
precio_mediana = 8.95

total_euros = (precio_familiar + precio_mediana)
total_unidades = (pizz_familiar + pizz_mediana)

print("Las pizzas en total seran:", total_unidades, "pizzas", "de las cuales", pizz_familiar, "pizzas familiares", "y", pizz_mediana, "pizza mediana")
print("Y el precio total son:", total_euros,"euros")

final_pregunta = (input("Alguna duda?"))

print("Le mandaremos las", total_unidades, "pizzas a la dirección", direcc, "Muchas gracias por su pedido.")
